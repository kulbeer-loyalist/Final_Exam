# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

def upload_data():
  print("Upload Data:")
  file_path=input("Enter the path of the file (.csv, .xlsx, .txt) or type 'manual' to enter data manually")
  if file_path.lower()=='manual':
    tips=input("Enter data separated by commas:")
    tips==[int(x) for x in tips.split(',')]
  else:
    tips=pd.read_csv(file_path)
  return tips


def labelencoding(tips):
  label_encoder=LabelEncoder()
  columns=['sex','smoker','day', 'time']
  for col in columns:
    tips[col] = label_encoder.fit_transform(tips[col])

def analyze_data(tips):
  print("Visualizing Data..")
  mean_value=np.mean(tips['tip'])
  plt.hist(tips['tip'],bins=10)
  plt.title("Histogram of Tips")
  plt.xlabel("Value")
  plt.ylabel("Frequency")
  plt.show()
  return mean_value
  plt.savefig("tips_mean.png")

def tips_smoking(tips):
  plt.figure(figsize=(6,6))
  sns.countplot(x="smoker",data=tips,palette="Set2")
  plt.title("Total tips based on smoker")
  plt.show()

def tips_days(tips):
  plt.figure(figsize=(6,6))
  sns.countplot(x="day",data=tips,palette="Set2")
  plt.title("Total tips based on day")
  plt.show()

def tips_sex(tips):
  plt.figure(figsize=(6,6))
  sns.countplot(x="sex",data=tips,palette="Set2")
  plt.title("Total tips based on gender")
  plt.show()

def tips_time(tips):
  plt.figure(figsize=(6,6))
  sns.countplot(x="time",data=tips,palette="Set2")
  plt.title("Total tips based on time")
  plt.show()

def bill(tips):
  plt.figure(figsize=(6,6))
  sns.countplot(x="sex",data=tips,palette="Set2")
  plt.title("Total tips based on gender")
  plt.show()

def correlation(tips):
  sns.heatmap(tips.corr(), annot = True)
  plt.show()

def main():
    # Upload data
    tips = upload_data()

    # Analyze data
    mean_value = analyze_data(tips)
    # View results
    print("Results:")
    print("Mean value:", mean_value)

    # tips based on smoking
    tips_smoking(tips)

     # tips based on days
    tips_days(tips)

     # tips based on gender
    tips_sex(tips)

     # tips based on gender
    tips_time(tips)

     # total bill based on gender
    bill(tips)

    # label encoding
    labelencoding(tips)

    # correlation matrix
    correlation(tips)

if __name__ == "__main__":
    main()
# Out:
# Upload Data:
# Enter the path of the file (.csv, .xlsx, .txt) or type 'manual' to enter data manually/content/tips.csv
# Visualizing Data..
# Results:
# Mean value: 2.99827868852459
# <ipython-input-2-bffe4c378a33>:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="smoker",data=tips,palette="Set2")
# <ipython-input-2-bffe4c378a33>:43: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="day",data=tips,palette="Set2")
# <ipython-input-2-bffe4c378a33>:49: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="sex",data=tips,palette="Set2")
# <ipython-input-2-bffe4c378a33>:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="time",data=tips,palette="Set2")
# <ipython-input-2-bffe4c378a33>:61: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="sex",data=tips,palette="Set2")
